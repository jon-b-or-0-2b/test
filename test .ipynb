# %%
import pandas as pd

# %%
df = pd.read_csv('results_multi_agent.csv')

# %%
df
# Out:
#                domain     value_type                   value  source  \
# 0  Solar Plant Design  land_required                  6 acre  page 1
# 1               cable        DC_side                  10 mm²  page 5
# 2               cable        AC_side  LT: 16mm² & HT: 185mm²  page 5
# 3               cable        HT_side                  185mm²  page 5
# 4               cable     quantities   As per Distance & Gap  page 5
#
#    confidence            agent
# 0           1  land_and_layout
# 1           1           cables
# 2           1           cables
# 3           1           cables
# 4           1           cables
